# %%
phone_numbers = [
    '1027865862',
    '1039685912',
    '1082442959',
    '1084317326',
    '1092446043',
    '1075681603',
    '1040219380',
    '1088947288',
    '1086800512',
    '1057927039',
    '1055453878',
    '1050367411',
    '1088693533',
    '1092730217',
    '010-6474-4389',
    '1020894401',
    '1096038566',
    '1047575865',
    '1083029689',
    '1039112047',
    '010-4802-9512',
    '1094790169',
    '010-4050-5729',
    '010-4617-6423',
    '010-9640-0039',
    '1020749049',
    '1084220896',
    '1036885282',
    '1051376996',
    '1049453896',
    '1050270522',
    '010-9929-2822',
    '1041886174',
    '1072126607',
    '010-5894-6250',
    '1028193529',
    '010-5648-9151',
    '1037089719',
    '1036803908',
    '1033161491',
    '1026278836',
    '1068035756',
    '1091589646',
    '1039521042',
    '1026328354',
    '1085216853',
    '1051632418',
    '1047325476',
    '1085924461',
    '1088191543',
    '1084372955',
    '010-5530-7719',
    '1058394322',
    '1092898792',
    '1094128362',
    '1086456890',
    '1085355184',
    '1082082950',
    '1066649205',
    '1023162420',
    '1033765171',
    '010-4046-4621',
    '1024305502',
    '1059239141',
    '1093651525',
    '1085527293'
]

# 10으로 시작하는 전화번호를 010으로 변경
for i in range(len(phone_numbers)):
    if phone_numbers[i].startswith('10'):
        phone_numbers[i] = '010' + phone_numbers[i][2:]

print(phone_numbers)
# Out:
# ['01027865862', '01039685912', '01082442959', '01084317326', '01092446043', '01075681603', '01040219380', '01088947288', '01086800512', '01057927039', '01055453878', '01050367411', '01088693533', '01092730217', '010-6474-4389', '01020894401', '01096038566', '01047575865', '01083029689', '01039112047', '010-4802-9512', '01094790169', '010-4050-5729', '010-4617-6423', '010-9640-0039', '01020749049', '01084220896', '01036885282', '01051376996', '01049453896', '01050270522', '010-9929-2822', '01041886174', '01072126607', '010-5894-6250', '01028193529', '010-5648-9151', '01037089719', '01036803908', '01033161491', '01026278836', '01068035756', '01091589646', '01039521042', '01026328354', '01085216853', '01051632418', '01047325476', '01085924461', '01088191543', '01084372955', '010-5530-7719', '01058394322', '01092898792', '01094128362', '01086456890', '01085355184', '01082082950', '01066649205', '01023162420', '01033765171', '010-4046-4621', '01024305502', '01059239141', '01093651525', '0
# ...

# %%
normalized_phone_numbers = []

for number in phone_numbers:
    normalized_number = number.replace('-', '')
    if len(normalized_number) == 11:
        normalized_number = normalized_number[:3] + '-' + normalized_number[3:7] + '-' + normalized_number[7:]  # 하이폰 추가
    normalized_phone_numbers.append(normalized_number)

print(normalized_phone_numbers)
# Out:
# ['010-2786-5862', '010-3968-5912', '010-8244-2959', '010-8431-7326', '010-9244-6043', '010-7568-1603', '010-4021-9380', '010-8894-7288', '010-8680-0512', '010-5792-7039', '010-5545-3878', '010-5036-7411', '010-8869-3533', '010-9273-0217', '010-6474-4389', '010-2089-4401', '010-9603-8566', '010-4757-5865', '010-8302-9689', '010-3911-2047', '010-4802-9512', '010-9479-0169', '010-4050-5729', '010-4617-6423', '010-9640-0039', '010-2074-9049', '010-8422-0896', '010-3688-5282', '010-5137-6996', '010-4945-3896', '010-5027-0522', '010-9929-2822', '010-4188-6174', '010-7212-6607', '010-5894-6250', '010-2819-3529', '010-5648-9151', '010-3708-9719', '010-3680-3908', '010-3316-1491', '010-2627-8836', '010-6803-5756', '010-9158-9646', '010-3952-1042', '010-2632-8354', '010-8521-6853', '010-5163-2418', '010-4732-5476', '010-8592-4461', '010-8819-1543', '010-8437-2955', '010-5530-7719', '010-5839-4322', '010-9289-8792', '010-9412-8362', '010-8645-6890', '010-8535-5184', '010-8208-2950', '010-6664-9
# ...

# %%
import random

prize = random.sample(normalized_phone_numbers, 10)
print(prize)
# Out:
# ['010-2074-9049', '010-4021-9380', '010-7568-1603', '010-6474-4389', '010-8431-7326', '010-8552-7293', '010-2786-5862', '010-5923-9141', '010-8869-3533', '010-4046-4621']
